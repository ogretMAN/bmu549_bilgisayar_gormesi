# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib.pyplot as plt
import numpy as np
from os import listdir
#import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
# Parametreler ayarlanıyor
data_dir = "/content/drive/My Drive/Piton_Uygulamalarim/raylar"
batch_size = 32
img_height = 540
img_width = 120

# %%
# Eğitim Verisi Ayarlanıyor
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1810 files belonging to 2 classes.
# Using 1448 files for training.

# %%
# Doğrulama Verisi Ayarlanıyor
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1810 files belonging to 2 classes.
# Using 362 files for validation.

# %%
# Sınıf İsimleri Sorgulanıyor
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Kirik', 'Saglam']

# %%
# Eğitim verilerinden 6 tanesini görüntüle
plt.figure(figsize=(5, 5))
for images, labels in train_ds.take(1):
  for i in range(6):
    ax = plt.subplot(2, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
# Verileri Standartlaştırma [0, 1] aralığı
normalization_layer = layers.Rescaling(1./255)

normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]

print("Resim 1'deki en küçük piksel değeri:", np.min(first_image), "en büyük piksel değeri:", np.max(first_image))
# Out:
# Resim 1'deki en küçük piksel değeri: 0.003921569 en büyük piksel değeri: 0.6862745

# %%
# Veri örneklerini büyütme
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %%
# Modeli Oluşturalım
num_classes = len(class_names)

model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='valid', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='valid', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='valid', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(128, 3, padding='valid', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.15), # Bırakma
  layers.Flatten(),
  layers.Dense(256, activation='relu'),
  layers.Dense(num_classes)
])

# %%
# Modeli Derleyelim
model.compile(optimizer='Adamax',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# Model Özet Bilgileri
model.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_16 (Sequential)  (None, 540, 120, 3)       0
#
#  rescaling_17 (Rescaling)    (None, 540, 120, 3)       0
#
#  conv2d_36 (Conv2D)          (None, 538, 118, 16)      448
#
#  max_pooling2d_36 (MaxPoolin  (None, 269, 59, 16)      0
#  g2D)
#
#  conv2d_37 (Conv2D)          (None, 267, 57, 32)       4640
#
#  max_pooling2d_37 (MaxPoolin  (None, 133, 28, 32)      0
#  g2D)
#
#  conv2d_38 (Conv2D)          (None, 131, 26, 64)       18496
#
#  max_pooling2d_38 (MaxPoolin  (None, 65, 13, 64)       0
#  g2D)
#
#  conv2d_39 (Conv2D)          (None, 63, 11, 128)       73856
#
#  max_pooling2d_39 (MaxPoolin  (None, 31, 5, 128)       0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 31, 5, 128)        0
#
#  flatten_9 (Flatten)         (None, 19840)             0
#
#  dense_18 (Dense)            (None, 256)               5079296
#
#  dense_19 (Dense)            (None, 2)                 514
#
# =================================================================
# Total params: 5,177,250
# Trainable params: 5,177,250
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Modelin Eğitilmesi
epochs=9
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/9
# 46/46 [==============================] - 113s 2s/step - loss: 0.7077 - accuracy: 0.5028 - val_loss: 0.6914 - val_accuracy: 0.6740
# Epoch 2/9
# 46/46 [==============================] - 111s 2s/step - loss: 0.6932 - accuracy: 0.5262 - val_loss: 0.6908 - val_accuracy: 0.6989
# Epoch 3/9
# 46/46 [==============================] - 110s 2s/step - loss: 0.6885 - accuracy: 0.5566 - val_loss: 0.6723 - val_accuracy: 0.6492
# Epoch 4/9
# 46/46 [==============================] - 109s 2s/step - loss: 0.6701 - accuracy: 0.5994 - val_loss: 0.6278 - val_accuracy: 0.7099
# Epoch 5/9
# 46/46 [==============================] - 109s 2s/step - loss: 0.6311 - accuracy: 0.6554 - val_loss: 0.5856 - val_accuracy: 0.6934
# Epoch 6/9
# 46/46 [==============================] - 110s 2s/step - loss: 0.5872 - accuracy: 0.6844 - val_loss: 0.5274 - val_accuracy: 0.7320
# Epoch 7/9
# 46/46 [==============================] - 111s 2s/step - loss: 0.5839 - accuracy: 0.6837 - val_loss: 0.5251 - val_accuracy: 0.7735
# Epoch 8/9
# 46/46 [==============================] - 109s 2s/step - loss: 0.5562 - accuracy: 0.7162 - val_loss: 0.5018 - val_accuracy: 0.7762
# Epoch 9/9
# 46/46 [==============================] - 110s 2s/step - loss: 0.5572 - accuracy: 0.7113 - val_loss: 0.5377 - val_accuracy: 0.7155

# %%
# Eğitim Sonuçlarının Görselleştirilmesi
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Eğitim')
plt.plot(epochs_range, val_acc, label='Doğrulama')
plt.legend(loc='lower right')
plt.title('Eğitim ve Doğrulama Neticesinde Kesinlik')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Eğitim')
plt.plot(epochs_range, val_loss, label='Doğrulama')
plt.legend(loc='upper right')
plt.title('Eğitim ve Doğrulama Neticesinde Kayıp')
plt.show()

# %%
# Yeni ray verilerini tahmin için gerekli fonksiyon hazırlanıyor
def tahmin(resim, gercek):
  konum = "/content/drive/My Drive/Piton_Uygulamalarim/test/"
  konum = konum + resim

  img = tf.keras.utils.load_img(
      konum, target_size=(img_height, img_width)
  )
  img_array = tf.keras.utils.img_to_array(img)
  img_array = tf.expand_dims(img_array, 0) # Create a batch

  predictions = model.predict(img_array)
  score = tf.nn.softmax(predictions[0])

  print(
      "GERÇEK SINIF: {} | TAHMİN EDİLEN: {} . Doğruluk Oranı: %{:.2f}"
      .format(gercek, class_names[np.argmax(score)], 100 * np.max(score))
  )

# %%
# Test klasöründeki tüm dosyaları okuyup tahmin edelim...
saglam_test_imgeleri = listdir("/content/drive/My Drive/Piton_Uygulamalarim/test/t_saglam/")
kirik_test_imgeleri = listdir("/content/drive/My Drive/Piton_Uygulamalarim/test/t_kirik/")

sSay = kSay = 1

for s_img in saglam_test_imgeleri:
  print(sSay, " ", end="")
  tahmin("t_saglam/" + s_img, "Saglam")
  sSay += 1

print(90 * "-")

for k_img in kirik_test_imgeleri:
  print(kSay, " ", end="")
  tahmin("t_kirik/" + k_img, "Kirik")
  kSay += 1
# Out:
# 1  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %75.65
# 2  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %80.22
# 3  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %74.72
# 4  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %74.66
# 5  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %52.58
# 6  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %82.64
# 7  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %51.35
# 8  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %85.89
# 9  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %81.04
# 10  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %50.26
# 11  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %65.91
# 12  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %71.57
# 13  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %54.95
# 14  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %65.97
# 15  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %71.91
# 16  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %66.67
# 17  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %67.34
# 18  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %79.82
# 19  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %66.23
# 20  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %77.98
# 21  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %70.68
# 22  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %71.66
# 23  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %70.03
# 24  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %53.24
# 25  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %58.56
# 26  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %51.76
# 27  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %81.27
# 28  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %56.42
# 29  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %73.38
# 30  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %81.72
# 31  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %84.34
# 32  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %85.05
# 33  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %76.44
# 34  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %71.76
# 35  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %77.03
# 36  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %66.98
# 37  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %71.94
# 38  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %70.39
# 39  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %77.84
# 40  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %64.72
# 41  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %58.87
# 42  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %56.19
# 43  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %68.09
# 44  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %58.96
# 45  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %76.24
# 46  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %67.31
# 47  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %51.85
# 48  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %76.89
# 49  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %65.10
# 50  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %66.65
# 51  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %69.39
# 52  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %71.26
# 53  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %71.55
# 54  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %75.69
# 55  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %60.18
# 56  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %63.91
# 57  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %67.32
# 58  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %63.18
# 59  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %62.64
# 60  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %57.51
# 61  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %65.77
# 62  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %52.92
# 63  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %50.94
# 64  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %80.21
# 65  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %65.96
# 66  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %80.89
# 67  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %58.19
# 68  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %72.97
# 69  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %68.46
# 70  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %71.29
# 71  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %79.55
# 72  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %78.41
# 73  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %71.58
# 74  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %62.71
# 75  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %68.16
# 76  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %52.96
# 77  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %70.11
# 78  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %56.32
# 79  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %60.49
# 80  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %56.70
# 81  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %79.42
# 82  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %73.49
# 83  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %55.47
# 84  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %80.15
# 85  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %73.31
# 86  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %57.32
# 87  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %72.92
# 88  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %84.04
# 89  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %89.06
# 90  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %64.69
# 91  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %69.42
# ------------------------------------------------------------------------------------------
# 1  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %74.20
# 2  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %68.26
# 3  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %86.83
# 4  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %83.77
# 5  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %65.19
# 6  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %65.22
# 7  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %65.17
# 8  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %72.57
# 9  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %54.53
# 10  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %62.21
# 11  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %69.87
# 12  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %51.52
# 13  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %78.74
# 14  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %82.75
# 15  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %53.35
# 16  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %64.33
# 17  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %77.75
# 18  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %51.15
# 19  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %59.16
# 20  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %77.70
# 21  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %88.44
# 22  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %74.36
# 23  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %76.62
# 24  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %76.16
# 25  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %89.48
# 26  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %66.06
# 27  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %83.18
# 28  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %67.81
# 29  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %86.60
# 30  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %92.41
# 31  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %58.92
# 32  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %55.66
# 33  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %74.23
# 34  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %74.81
# 35  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %67.01
# 36  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %66.96
# 37  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %70.65
# 38  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %51.05
# 39  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %51.13
# 40  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %61.42
# 41  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %59.80
# 42  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %60.79
# 43  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %77.07
# 44  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %70.32
# 45  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %62.06
# 46  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %60.08
# 47  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %73.06
# 48  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %74.12
# 49  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %77.09
# 50  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %83.29
# 51  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %84.02
# 52  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %82.77
# 53  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %81.65
# 54  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %83.43
# 55  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %74.46
# 56  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %76.56
# 57  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %77.78
# 58  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %77.57
# 59  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %78.63
# 60  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %77.37
# 61  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %74.99
# 62  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %85.42
# 63  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %75.86
# 64  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %77.89
# 65  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %76.05
# 66  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %78.66
# 67  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %74.51
# 68  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %73.12
# 69  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %71.21
# 70  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %80.49
# 71  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %79.07
# 72  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %81.57
# 73  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %80.32
# 74  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %77.10
# 75  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %78.11
# 76  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %81.93
# 77  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %79.03
# 78  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %78.38
# 79  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %78.87
# 80  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %82.83
# 81  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %75.50
# 82  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %56.70
# 83  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %76.90
# 84  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %74.66
# 85  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %52.05
# 86  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %77.42
# 87  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %79.78
# 88  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %51.83
# 89  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %50.17
# 90  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %65.89
# 91  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %58.41
# 92  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %75.87
# 93  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %67.84
# 94  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %70.38
# 95  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %68.85
# 96  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %64.34
# 97  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %70.36
# 98  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %91.14
# 99  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %69.01
