# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib.pyplot as plt
import numpy as np
from os import listdir
#import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
# Parametreler ayarlanıyor
data_dir = "/content/drive/My Drive/Piton_Uygulamalarim/raylar"
batch_size = 32
img_height = 540
img_width = 120

# %%
# Eğitim Verisi Ayarlanıyor
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1810 files belonging to 2 classes.
# Using 1448 files for training.

# %%
# Doğrulama Verisi Ayarlanıyor
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1810 files belonging to 2 classes.
# Using 362 files for validation.

# %%
# Sınıf İsimleri Sorgulanıyor
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Kirik', 'Saglam']

# %%
# Eğitim verilerinden 6 tanesini görüntüle
plt.figure(figsize=(5, 5))
for images, labels in train_ds.take(1):
  for i in range(6):
    ax = plt.subplot(2, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
# Verileri Standartlaştırma [0, 1] aralığı
normalization_layer = layers.Rescaling(1./255)

normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]

print("Resim 1'deki en küçük piksel değeri:", np.min(first_image), "en büyük piksel değeri:", np.max(first_image))
# Out:
# Resim 1'deki en küçük piksel değeri: 0.003921569 en büyük piksel değeri: 0.6862745

# %%
# Veri örneklerini büyütme
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %%
# Modeli Oluşturalım
num_classes = len(class_names)

model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(128, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.15), # Bırakma
  layers.Flatten(),
  layers.Dense(256, activation='relu'),
  layers.Dense(num_classes)
])

# %%
# Modeli Derleyelim
model.compile(optimizer='Adamax',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# Model Özet Bilgileri
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_8 (Sequential)   (None, 540, 120, 3)       0
#
#  rescaling_9 (Rescaling)     (None, 540, 120, 3)       0
#
#  conv2d_20 (Conv2D)          (None, 540, 120, 16)      448
#
#  max_pooling2d_20 (MaxPoolin  (None, 270, 60, 16)      0
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 270, 60, 32)       4640
#
#  max_pooling2d_21 (MaxPoolin  (None, 135, 30, 32)      0
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 135, 30, 64)       18496
#
#  max_pooling2d_22 (MaxPoolin  (None, 67, 15, 64)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 67, 15, 128)       73856
#
#  max_pooling2d_23 (MaxPoolin  (None, 33, 7, 128)       0
#  g2D)
#
#  dropout_5 (Dropout)         (None, 33, 7, 128)        0
#
#  flatten_5 (Flatten)         (None, 29568)             0
#
#  dense_10 (Dense)            (None, 256)               7569664
#
#  dense_11 (Dense)            (None, 2)                 514
#
# =================================================================
# Total params: 7,667,618
# Trainable params: 7,667,618
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Modelin Eğitilmesi
epochs=15
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/15
# 46/46 [==============================] - 120s 3s/step - loss: 0.7612 - accuracy: 0.4883 - val_loss: 0.6926 - val_accuracy: 0.5083
# Epoch 2/15
# 46/46 [==============================] - 119s 3s/step - loss: 0.6927 - accuracy: 0.5138 - val_loss: 0.6917 - val_accuracy: 0.4917
# Epoch 3/15
# 46/46 [==============================] - 117s 3s/step - loss: 0.6907 - accuracy: 0.5242 - val_loss: 0.6896 - val_accuracy: 0.4945
# Epoch 4/15
# 46/46 [==============================] - 117s 3s/step - loss: 0.6859 - accuracy: 0.5352 - val_loss: 0.6734 - val_accuracy: 0.6768
# Epoch 5/15
# 46/46 [==============================] - 118s 3s/step - loss: 0.6815 - accuracy: 0.5401 - val_loss: 0.6592 - val_accuracy: 0.6961
# Epoch 6/15
# 46/46 [==============================] - 120s 3s/step - loss: 0.6631 - accuracy: 0.6001 - val_loss: 0.6404 - val_accuracy: 0.6657
# Epoch 7/15
# 46/46 [==============================] - 119s 3s/step - loss: 0.6500 - accuracy: 0.6347 - val_loss: 0.6178 - val_accuracy: 0.6381
# Epoch 8/15
# 46/46 [==============================] - 119s 3s/step - loss: 0.5929 - accuracy: 0.7044 - val_loss: 0.5469 - val_accuracy: 0.7127
# Epoch 9/15
# 46/46 [==============================] - 119s 3s/step - loss: 0.5602 - accuracy: 0.7231 - val_loss: 0.5055 - val_accuracy: 0.7569
# Epoch 10/15
# 46/46 [==============================] - 119s 3s/step - loss: 0.5799 - accuracy: 0.7003 - val_loss: 0.5088 - val_accuracy: 0.7680
# Epoch 11/15
# 46/46 [==============================] - 119s 3s/step - loss: 0.5439 - accuracy: 0.7258 - val_loss: 0.4892 - val_accuracy: 0.7762
# Epoch 12/15
# 46/46 [==============================] - 120s 3s/step - loss: 0.5604 - accuracy: 0.7148 - val_loss: 0.5498 - val_accuracy: 0.7238
# Epoch 13/15
# 46/46 [==============================] - 122s 3s/step - loss: 0.5436 - accuracy: 0.7327 - val_loss: 0.4728 - val_accuracy: 0.7845
# Epoch 14/15
# 46/46 [==============================] - 121s 3s/step - loss: 0.5225 - accuracy: 0.7417 - val_loss: 0.4719 - val_accuracy: 0.7762
# Epoch 15/15
# 46/46 [==============================] - 119s 3s/step - loss: 0.5350 - accuracy: 0.7272 - val_loss: 0.4813 - val_accuracy: 0.7624

# %%
# Eğitim Sonuçlarının Görselleştirilmesi
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Eğitim')
plt.plot(epochs_range, val_acc, label='Doğrulama')
plt.legend(loc='lower right')
plt.title('Eğitim ve Doğrulama Neticesinde Kesinlik')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Eğitim')
plt.plot(epochs_range, val_loss, label='Doğrulama')
plt.legend(loc='upper right')
plt.title('Eğitim ve Doğrulama Neticesinde Kayıp')
plt.show()

# %%
# Yeni ray verilerini tahmin için gerekli fonksiyon hazırlanıyor
def tahmin(resim, gercek):
  konum = "/content/drive/My Drive/Piton_Uygulamalarim/test/"
  konum = konum + resim

  img = tf.keras.utils.load_img(
      konum, target_size=(img_height, img_width)
  )
  img_array = tf.keras.utils.img_to_array(img)
  img_array = tf.expand_dims(img_array, 0) # Create a batch

  predictions = model.predict(img_array)
  score = tf.nn.softmax(predictions[0])

  print(
      "GERÇEK SINIF: {} | TAHMİN EDİLEN: {} . Doğruluk Oranı: %{:.2f}"
      .format(gercek, class_names[np.argmax(score)], 100 * np.max(score))
  )

# %%
# Test klasöründeki tüm dosyaları okuyup tahmin edelim...
saglam_test_imgeleri = listdir("/content/drive/My Drive/Piton_Uygulamalarim/test/t_saglam/")
kirik_test_imgeleri = listdir("/content/drive/My Drive/Piton_Uygulamalarim/test/t_kirik/")

sSay = kSay = 1

for s_img in saglam_test_imgeleri:
  print(sSay, " ", end="")
  tahmin("t_saglam/" + s_img, "Saglam")
  sSay += 1

print(90 * "-")

for k_img in kirik_test_imgeleri:
  print(kSay, " ", end="")
  tahmin("t_kirik/" + k_img, "Kirik")
  kSay += 1
# Out:
# 1  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %63.35
# 2  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %66.15
# 3  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %50.33
# 4  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %62.34
# 5  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %86.39
# 6  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %93.06
# 7  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %75.03
# 8  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %94.07
# 9  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %90.25
# 10  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %65.75
# 11  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %85.18
# 12  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %52.86
# 13  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %58.11
# 14  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %82.38
# 15  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %88.96
# 16  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %73.77
# 17  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %88.67
# 18  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %73.58
# 19  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %62.45
# 20  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %53.38
# 21  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %65.10
# 22  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %66.12
# 23  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %66.79
# 24  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %57.33
# 25  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %58.89
# 26  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %67.40
# 27  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %92.45
# 28  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %74.19
# 29  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %68.97
# 30  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %93.45
# 31  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %93.62
# 32  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %93.85
# 33  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %71.03
# 34  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %73.37
# 35  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %56.45
# 36  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %52.73
# 37  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %65.46
# 38  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %58.65
# 39  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %92.87
# 40  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %69.04
# 41  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %71.44
# 42  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %69.75
# 43  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %86.88
# 44  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %75.44
# 45  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %72.52
# 46  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %53.15
# 47  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %72.99
# 48  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %69.68
# 49  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %52.46
# 50  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %86.83
# 51  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %67.23
# 52  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %60.28
# 53  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %63.52
# 54  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %50.91
# 55  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %85.44
# 56  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %78.16
# 57  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %58.32
# 58  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %66.35
# 59  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %86.78
# 60  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %94.74
# 61  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %83.60
# 62  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %87.23
# 63  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %91.37
# 64  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %93.63
# 65  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %87.06
# 66  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %78.56
# 67  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %95.92
# 68  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %95.78
# 69  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %59.51
# 70  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %96.70
# 71  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %90.34
# 72  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %93.05
# 73  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %64.65
# 74  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %80.01
# 75  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %91.75
# 76  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %91.74
# 77  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %75.41
# 78  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %77.35
# 79  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %81.55
# 80  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %70.65
# 81  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %92.95
# 82  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %54.94
# 83  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %76.95
# 84  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %91.74
# 85  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %50.64
# 86  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %80.24
# 87  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %55.03
# 88  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %89.66
# 89  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %95.66
# 90  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %71.29
# 91  GERÇEK SINIF: Saglam | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %79.52
# ------------------------------------------------------------------------------------------
# 1  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %86.02
# 2  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %68.00
# 3  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %70.95
# 4  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %72.72
# 5  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %52.96
# 6  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %56.46
# 7  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %53.65
# 8  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %59.89
# 9  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %64.26
# 10  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %59.04
# 11  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %53.31
# 12  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %51.73
# 13  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %62.18
# 14  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %58.50
# 15  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %70.42
# 16  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %63.24
# 17  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %62.15
# 18  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %68.01
# 19  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %59.85
# 20  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %65.48
# 21  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %82.31
# 22  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %60.75
# 23  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %79.19
# 24  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %50.29
# 25  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %92.32
# 26  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %71.00
# 27  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %54.80
# 28  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %80.43
# 29  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %70.90
# 30  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %91.25
# 31  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %68.85
# 32  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %74.39
# 33  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %78.80
# 34  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %54.61
# 35  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %55.25
# 36  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %57.01
# 37  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %58.01
# 38  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %71.08
# 39  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %51.28
# 40  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %76.18
# 41  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %76.90
# 42  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %52.82
# 43  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %81.01
# 44  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %61.39
# 45  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %75.67
# 46  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %56.00
# 47  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %50.35
# 48  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %71.73
# 49  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %52.41
# 50  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %93.90
# 51  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %80.93
# 52  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %52.22
# 53  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %64.92
# 54  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %71.13
# 55  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %52.25
# 56  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %65.05
# 57  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %50.52
# 58  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %58.50
# 59  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %67.15
# 60  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %52.15
# 61  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %66.32
# 62  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %82.91
# 63  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %66.95
# 64  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %64.67
# 65  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %71.79
# 66  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %67.20
# 67  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %62.64
# 68  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %51.00
# 69  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %55.90
# 70  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %64.05
# 71  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %54.41
# 72  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %60.16
# 73  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %56.01
# 74  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %69.46
# 75  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %81.90
# 76  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %71.32
# 77  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %70.24
# 78  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %51.25
# 79  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %55.79
# 80  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %70.65
# 81  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %68.50
# 82  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %68.72
# 83  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %57.68
# 84  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %62.34
# 85  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %65.26
# 86  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %59.93
# 87  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %56.09
# 88  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %74.20
# 89  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %63.04
# 90  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %51.59
# 91  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %51.02
# 92  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %61.97
# 93  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %50.94
# 94  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %76.28
# 95  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %67.24
# 96  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %73.97
# 97  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %72.85
# 98  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Kirik . Doğruluk Oranı: %84.54
# 99  GERÇEK SINIF: Kirik | TAHMİN EDİLEN: Saglam . Doğruluk Oranı: %50.60
